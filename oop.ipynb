# %% [markdown]
# <a href="https://colab.research.google.com/github/likhithabalgam19/Task-Aiml/blob/main/oop.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **OOP in python**

# %%
class Person:
   name = "Kartik"

p = Person()
q = Person()
print(p.name)
print (q.name)
# Out:
# Kartik
# Kartik

# %%
class Emp :
  eid = 101
  ename = 'Karthik'

obj = Emp()
print('the employee id is :',obj.eid,'and the emp name is :',obj.ename)
# Out:
# the employee id is : 101 and the emp name is : Karthik

# %%
class student:

  def __init__(self,name,age):
    self.name = name
    self.age = age
s1 = student("Likitha",21)

print("Name :",s1.name)
print("Age :",s1.age)
# Out:
# Name : Likitha
# Age : 21

# %%
class student:
  def __init__(self,name):
    self.name = name

  def display(self):
    print("name of the student: ",self.name)

s1 = student("Likhitha")
s1.display()
# Out:
# name of the student:  Likhitha

# %%
class Dog:
    species = "Canine"  # Class attribute

    def __init__(self, name, age):
        self.name = name
        self.age = age

    def dog_name(self, dog, cat):
        self.dog = dog
        self.cat = cat
        print("Dog name:", self.dog)
        print("Cat name:", self.cat)

# %%
# Taking input from user
name = input("Enter dog object name: ")
age = int(input("Enter age: "))

dog_value = input("Enter dog name: ")
cat_value = input("Enter cat name: ")

# Creating object
d = Dog(name, age)

# Calling function with user input
d.dog_name(dog_value, cat_value)
# Out:
# Enter dog object name: bb
# Enter age: 32
# Enter dog name: cc
# Enter cat name: bb
# Dog name: cc
# Cat name: bb

# %%
class Car:

    price = 500000

    def show(self,color,brand):
        self.color= color
        self.brand = brand
        print(f"The {self.color} color of {self.brand} is wonderful")

c = Car()
car_color = "Blue"
brand_name = "Toyota"
c.show (car_color,brand_name)
print (c.price)
# Out:
# The Blue color of Toyota is wonderful
# 500000
